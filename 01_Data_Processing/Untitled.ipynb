# %%
import pandas as pd

# %%
ny = pd.read_csv('NYtwitter_output_10_1.csv')
ny.sample(10)
# Out:
#             tract  total_tweets  miss_home_tract  userwith5_count  \
# 2774  36081039900          5766         0.000000               99
# 808   34031246002         14554         0.000000              132
# 911   34039037900          7120         0.000000              141
# 239   34013006200         21213         0.000000              169
# 632   34023004300         20545         0.000000              171
# 3232  36085014700         21748         0.000525              357
# 675   34025800500          4978         0.001164               46
# 969   36005006300        101065         0.000114             3655
# 1692  36047050202          2182         0.000000               64
# 2934  36081062700          8082         0.000000               80
#
#       total_users  tweets_hometract  tweets_sent_from_home  oddratio_12AM  \
# 2774         1131              5766                   1722       0.068678
# 808           409             14554                  12444       0.088910
# ...
